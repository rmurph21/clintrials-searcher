# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import json
from datetime import datetime
import string

# %%
def parse_drug_name(drug_name):
    table = str.maketrans(dict.fromkeys(string.punctuation))
    drug_name_parsed = drug_name.translate(table)
    drug_name = drug_name.replace("-", " ")
    drug_name = drug_name.lower()
    #tokens = nltk.word_tokenize(drug_name)
    #tokens = set(tokens)
    
    return drug_name

# %%
# method for getting clinicaltrials.gov info for given company
def get_clinical_trials(company_name):
    
    ## clinicaltrials.gov searcher
    clintrials_base_url = "https://clinicaltrials.gov/api/query/study_fields"
    expr = "'" + company_name + "'"    
    
    fmt = "JSON"
    min_rnk = 1
    max_rnk = 1000
    fields1 = ','.join([
        'OrgFullName',
        'NCTId',
        'BriefTitle',
        'OfficialTitle',
        'DesignAllocation',
        'Acronym',
        'Phase',
        'OverallStatus',
        'DesignMasking',
        'StartDate',
        'EnrollmentCount',
        'EnrollmentType',
        'ArmGroupDescription',
        'ArmGroupInterventionName',
        'ArmGroupLabel',
        'ArmGroupType',
        'InterventionType',
        'InterventionName',
        'InterventionDescription',
        'InterventionArmGroupLabel'
    ])

    fields2 = ','.join([
        'PrimaryOutcomeMeasure',
        'NCTId',
        'PrimaryOutcomeDescription',
        'PrimaryOutcomeTimeFrame',
        'SecondaryOutcomeMeasure',
        'SecondaryOutcomeDescription',
        'SecondaryOutcomeTimeFrame',
        'EligibilityCriteria',
        'ConditionMeshId',
        'ConditionMeshTerm',
        'InterventionMeshId',
        'InterventionMeshTerm',
        'InterventionAncestorId',
        'InterventionAncestorTerm',
        'InterventionBrowseLeafId',
        'InterventionBrowseLeafName',
        'InterventionBrowseLeafAsFound',
        'InterventionBrowseLeafRelevance',
        'PrimaryCompletionDate',
        'CompletionDate'    
    ])

    fields3 = ','.join([
        'LeadSponsorName',
        'NCTId',
        'ResponsiblePartyType',
        'LeadSponsorClass',
        'IsFDARegulatedDrug',
        'BriefSummary',
        'DetailedDescription',
        'Condition',
        'Keyword',
        'StudyType',
        'DesignInterventionModel',
        'DesignPrimaryPurpose'
    ])

    clin_payload1 = {"expr": expr, "min_rnk": min_rnk, "max_rnk": max_rnk, "fmt": fmt, "fields": fields1}
    clin_payload2 = {"expr": expr, "min_rnk": min_rnk, "max_rnk": max_rnk, "fmt": fmt, "fields": fields2}
    clin_payload3 = {"expr": expr, "min_rnk": min_rnk, "max_rnk": max_rnk, "fmt": fmt, "fields": fields3}
    # make sure to add quotes to all terms so results are required to match
    
    clin_r1 = requests.get(clintrials_base_url, params=clin_payload1)
    clin_r2 = requests.get(clintrials_base_url, params=clin_payload2)
    clin_r3 = requests.get(clintrials_base_url, params=clin_payload3)
    
    clin_r1_dict = clin_r1.json()["StudyFieldsResponse"]["StudyFields"]
    for r1_dict in clin_r1_dict:
        for r1_key in r1_dict:
            if isinstance(r1_dict[r1_key], list):
                r1_dict[r1_key] = ", ".join(r1_dict[r1_key])
    
    clin_r2_dict = clin_r2.json()["StudyFieldsResponse"]["StudyFields"]
    for r2_dict in clin_r2_dict:
        for key in r2_dict:
            if isinstance(r2_dict[key], list):
                r2_dict[key] = ", ".join(r2_dict[key])
    
    clin_r3_dict = clin_r3.json()["StudyFieldsResponse"]["StudyFields"]
    for r3_dict in clin_r3_dict:
        for key in r3_dict:
            if isinstance(r3_dict[key], list):
                r3_dict[key] = ", ".join(r3_dict[key])
    
    try:
        
        if "StudyFields" in clin_r1.json()["StudyFieldsResponse"]:

            if clin_r1.status_code == 200:
                clin1_df = pd.DataFrame(clin_r1_dict)
            else:
                clin1_df = pd.DataFrame()
            if clin_r2.status_code == 200:
                clin2_df = pd.DataFrame(clin_r2_dict)
            else:
                clin2_df = pd.DataFrame()
            if clin_r3.status_code == 200:
                clin3_df = pd.DataFrame(clin_r3_dict)
            else:
                clin3_df = pd.DataFrame()

            list_clin1_org = []
            for row in clin1_df['OrgFullName']:
                list_clin1_org.append(row)

            list_clin1_nct = []
            for row in clin1_df['NCTId']:
                list_clin1_nct.append(row)

            list_clin2_nct = []
            for row in clin2_df['NCTId']:
                list_clin2_nct.append(row)

            list_clin3_nct = []
            for row in clin3_df['NCTId']:
                list_clin3_nct.append(row)

            clin1_df["Company_name"] = list_clin1_org
            clin1_df["NCT_ID_new"] = list_clin1_nct
            clin2_df["NCT_ID_new"] = list_clin2_nct
            clin3_df["NCT_ID_new"] = list_clin3_nct
            clin3_df["EDGAR_name"] = company_name

            clin_all_df = clin1_df.join(clin2_df.set_index("NCT_ID_new"), on="NCT_ID_new", rsuffix="_2").join(clin3_df.set_index("NCT_ID_new"), on="NCT_ID_new", rsuffix="_3")

            clin_all_df = clin_all_df[clin_all_df["Company_name"].str.contains(company_name, case=False)]

            return clin_all_df

        else:
            clin_all_df = pd.DataFrame()
            return clin_all_df
    
    except:
        
        empty_df = pd.DataFrame()
        
        return "error"

# %%
def clinical_trials_with_drug(trials_df, drug_names):
    filtered_trials = []
    trials_df_dict = trials_df.to_dict('records')
    for i in trials_df_dict:
        for drug_name in drug_names:
            if parse_drug_name(drug_name) in parse_drug_name(i["InterventionName"]):
                filtered_trials.append(i)
    
    filtered_trials_df = pd.DataFrame(filtered_trials)
    
    return filtered_trials_df

# %%
# company name is string, drug_names (optional) is list
def clinical_trials_company_drugs(company_name, drug_names=[]):
    
    co_trials = get_clinical_trials(company_name)
    
    if co_trials.empty:
        
        return "no trials for company, check spelling of company name"
    
    else:
        
        if drug_names:
    
            trials = clinical_trials_with_drug(co_trials, drug_names)

            return trials
        else:
            
            return co_trials

# %%
clinical_trials_company_drugs("Nektar Therapeutics")
# Out:
#     Rank          OrgFullName        NCTId  \
# 0      1  Nektar Therapeutics  NCT01619839
# 1      2  Nektar Therapeutics  NCT01492101
# 2      3  Nektar Therapeutics  NCT03729245
# 3      4  Nektar Therapeutics  NCT04136756
# 4      5  Nektar Therapeutics  NCT03435640
# 5      6  Nektar Therapeutics  NCT04646044
# 6      7  Nektar Therapeutics  NCT02983045
# 7      8  Nektar Therapeutics  NCT04616196
# 8      9  Nektar Therapeutics  NCT03138889
# 9     10  Nektar Therapeutics  NCT00802945
# 10    11  Nektar Therapeutics  NCT00598975
# 11    12  Nektar Therapeutics  NCT04410445
# 12    13  Nektar Therapeutics  NCT01457118
# 13    14  Nektar Therapeutics  NCT00856375
# 14    15  Nektar Therapeutics  NCT00806156
# 15    16  Nektar Therapeutics  NCT03785925
# 16    17  Nektar Therapeutics  NCT01991678
# 17    18  Nektar Therapeutics  NCT01976143
# 18    19  Nektar Therapeutics  NCT02915744
# 19    20  Nektar Therapeutics  NCT02362672
# 20    21  Nektar Therapeutics  NCT02367820
# 21    22  Nektar Therapeutics  NCT03802227
# 22    23  Nektar Therapeutics  NCT02869295
#
#                                            BriefTitle  \
# 0   A Phase 2 Study To Assess The Efficacy, Tolera...
# 1   The BEACON Study (Breast Cancer Outcomes With ...
# 2   A Study of Bempegaldesleukin (NKTR-214: BEMPEG...
# 3   NKTR-255 in Relapsed/Refractory Multiple Myelo...
# 4   A Study of NKTR-262 in Combination With Bempeg...
# 5   A Placebo Controlled Trial of Bempegaldesleuki...
# 6   A Dose Escalation and Cohort Expansion Study o...
# 7   Study of NKTR 255 in Combination With Cetuxima...
# 8   A Study of a CD122-Biased Cytokine (NKTR-214) ...
# 9   Study to Evaluate the Safety and Efficacy of N...
# 10  A Phase 2a/2b Multicenter, Open-Label Study to...
# 11  Study to Compare Adjuvant Immunotherapy of Bem...
# 12  An Extension Study of NKTR-102 in Cancer Patie...
# 13  NKTR-102 Versus Irinotecan in Patients With Se...
# 14  Study to Evaluate the Safety and Efficacy of N...
# 15  A Single-Arm Study of Bempegaldesleukin (NKTR-...
# 16  A Study in Cancer Patients With Hepatic Impair...
# 17  A Study in Cancer Patients to Evaluate the Eff...
# 18  A Study of Etirinotecan Pegol (NKTR-102) Versu...
# 19  Efficacy and Safety Study of NKTR-181 in Opioi...
# 20  Long-Term Safety and Tolerability Study of NKT...
# 21  A Study Using Functional Magnetic Resonance Im...
# 22  A Phase 1/2 Multicenter Dose Escalation and Ex...
#
#                                         OfficialTitle DesignAllocation  \
# 0   A Phase 2, Enriched-Enrollment, Randomized-Wit...       Randomized
# 1   The BEACON Study (Breast Cancer Outcomes With ...       Randomized
# 2   A Phase 3 Randomized Open Label Study to Compa...       Randomized
# 3   A Phase 1, Open-label, Multi-center, Dose Esca...   Non-Randomized
# 4   A Phase 1/2, Open-label, Multicenter, Dose Esc...   Non-Randomized
# 5   A Phase 1b, Multicenter, Randomized, Double-Bl...       Randomized
# 6   A Phase 1/2, Open-label, Multicenter Study of ...   Non-Randomized
# 7   A Phase 1b/2, Open-label, Multicenter, Dose Es...   Non-Randomized
# 8   A Phase 1/2, Open-Label, Multicenter Study to ...   Non-Randomized
# 9   A Multicenter, Open-Label, Phase 2 Study to Ev...       Randomized
# 10  A Multicenter, Open-Label, Phase 2 Study to De...              N/A
# 11  A Phase 3, Randomized, Open-label Study to Com...       Randomized
# 12  An Open-Label, Multicenter, Extension Study of...              N/A
# 13  A Multicenter, Open-Label, Randomized, Phase 2...       Randomized
# 14  A Multicenter, Open-Label, Phase 2 Study to Ev...       Randomized
# 15  A Phase 2, Single-Arm Study of Bempegaldesleuk...              N/A
# 16  An Open-Label, Parallel-Group, Multicenter, Ph...   Non-Randomized
# 17  A Phase 1 Study to Evaluate the Effect of Nktr...              N/A
# 18  A Phase 3 Open-Label, Randomized, Multicenter ...       Randomized
# 19  A Phase 3 Double-Blind, Placebo-Controlled Stu...       Randomized
# 20  A Phase 3 Multicenter, Open-Label, 52-Week Stu...              N/A
# 21  A Phase 1 Double-Blind, Double-Dummy, Parallel...       Randomized
# 22  An Open-Label, Multicenter, Dose Escalation An...              N/A
#
#        Acronym             Phase           OverallStatus      DesignMasking  \
# 0                        Phase 2               Completed          Quadruple
# 1       BEACON           Phase 3               Completed  None (Open Label)
# 2                        Phase 3              Recruiting  None (Open Label)
# 3                        Phase 1              Recruiting  None (Open Label)
# 4       REVEAL  Phase 1, Phase 2              Recruiting  None (Open Label)
# 5                        Phase 1              Recruiting             Double
# 6     PIVOT-02  Phase 1, Phase 2  Active, not recruiting  None (Open Label)
# 7               Phase 1, Phase 2              Recruiting  None (Open Label)
# 8       PROPEL  Phase 1, Phase 2              Recruiting  None (Open Label)
# 9                        Phase 2               Completed  None (Open Label)
# 10                       Phase 2               Completed  None (Open Label)
# 11    PIVOT-12           Phase 3              Recruiting  None (Open Label)
# 12                       Phase 2               Completed  None (Open Label)
# 13                       Phase 2               Completed  None (Open Label)
# 14                       Phase 2               Completed  None (Open Label)
# 15    PIVOT-10           Phase 2  Active, not recruiting  None (Open Label)
# 16                       Phase 1               Completed  None (Open Label)
# 17                       Phase 1               Completed  None (Open Label)
# 18      ATTAIN           Phase 3               Completed  None (Open Label)
# 19   SUMMIT-07           Phase 3               Completed          Quadruple
# 20  SUMMIT-LTS           Phase 3               Completed  None (Open Label)
# 21                       Phase 1              Terminated             Triple
# 22    NKTR-214  Phase 1, Phase 2               Completed  None (Open Label)
#
#     ... LeadSponsorClass IsFDARegulatedDrug  \
# 0   ...         INDUSTRY
# 1   ...         INDUSTRY
# 2   ...         INDUSTRY                Yes
# 3   ...         INDUSTRY                Yes
# 4   ...         INDUSTRY                Yes
# 5   ...         INDUSTRY                Yes
# 6   ...         INDUSTRY                Yes
# 7   ...         INDUSTRY                Yes
# 8   ...         INDUSTRY                Yes
# 9   ...         INDUSTRY
# 10  ...         INDUSTRY
# 11  ...         INDUSTRY                Yes
# 12  ...         INDUSTRY
# 13  ...         INDUSTRY
# 14  ...         INDUSTRY
# 15  ...         INDUSTRY                Yes
# 16  ...         INDUSTRY
# 17  ...         INDUSTRY
# 18  ...         INDUSTRY
# 19  ...         INDUSTRY
# 20  ...         INDUSTRY
# 21  ...         INDUSTRY                Yes
# 22  ...         INDUSTRY
#
#                                          BriefSummary  \
# 0   NKTR-181 is being developed as an analgesic co...
# 1   The study is designed as an open-label, random...
# 2   The main purpose of this study is to compare t...
# 3   Patients will receive intravenous (IV) NKTR-25...
# 4   Patients will receive intra-tumoral (IT) NKTR-...
# 5   The main purpose of this phase-1b, multicenter...
# 6   In this four-part study, NKTR-214 will be admi...
# 7   Patients with relapsed or refractory (R/R) hea...
# 8   This study is to assess the safety and tolerab...
# 9   This is a multicenter, open-label, two-arm, 2-...
# 10  Study 07-PIR-02 is a Phase 2 study designed to...
# 11  The main purpose of this study is to compare t...
# 12  The study objective of this open label, multic...
# 13  This study will evaluate whether NKTR-102, an ...
# 14  This is a multicenter, open-label, two-arm, 2-...
# 15  The main purpose of this study is to evaluate ...
# 16  The purpose of this study is to investigate th...
# 17  The purpose of this research study is to evalu...
# 18  This is an open-label, randomized, active comp...
# 19  The purpose of this study is to determine whet...
# 20  The purpose of this 52-week open label study i...
# 21  The main purpose of this study is to evaluate ...
# 22  This is a first in human, open-label, sequenti...
#
#                                   DetailedDescription  \
# 0
# 1
# 2
# 3   NKTR-255 is a cytokine that is designed to reg...
# 4   Cancer treatments that couple pharmacological ...
# 5
# 6   NKTR-214 (investigational agent) is an IL-2 pa...
# 7   This study is a Phase 1b/2, open-label, multic...
# 8   NKTR-214 is a cytokine (investigational agent)...
# 9
# 10  The Phase 2a portion of this study is complete...
# 11  The main purpose of this study is to compare t...
# 12
# 13
# 14
# 15
# 16  Safety and PK data from patients with mild, mo...
# 17  This is an open-label study that will assess t...
# 18  This is an open-label, randomized, active comp...
# 19  This is an enriched enrollment, randomized wit...
# 20  This is an open-label safety and tolerability ...
# 21  This study is a single-center study in which a...
# 22
#
#                                             Condition  \
# 0                          Osteoarthritis of the Knee
# 1   Locally Recurrent Breast Cancer, Metastatic Br...
# 2   Renal Cell Carcinoma, Metastatic Renal Cell Ca...
# 3   Multiple Myeloma, Non-Hodgkin Lymphoma, Indole...
# 4   Melanoma, Merkel Cell Carcinoma, Triple Negati...
# 5                  Covid-19, Coronavirus Disease 2019
# 6   Melanoma, Renal Cell Carcinoma, Non Small Cell...
# 7   Head and Neck Squamous Cell Carcinoma (HNSCC),...
# 8   Non-Small Cell Lung Cancer, Melanoma, Urotheli...
# 9                                Tumor, Breast Cancer
# 10                           Tumor, Colorectal Cancer
# 11  Melanoma, Melanoma Stage III, Melanoma Stage I...
# 12                              Malignant Solid Tumor
# 13                                  Colorectal Cancer
# 14                              Tumor, Ovarian Cancer
# 15      Urinary Bladder Neoplasm, Neoplasm Metastasis
# 16  Advanced or Metastatic Solid Tumors in Patient...
# 17           Advanced Cancer, Metastatic Solid Tumors
# 18                          Metastasis, Breast Cancer
# 19                        Low Back Pain, Chronic Pain
# 20                        Low Back Pain, Chronic Pain
# 21                    Moderate to Severe Chronic Pain
# 22   Unspecified Adult Solid Tumor, Protocol Specific
#
#                                               Keyword       StudyType  \
# 0                                    Nektar, NKTR-181  Interventional
# 1                                                      Interventional
# 2   Kidney Cancer, Kidney Neoplasms, Renal Cancer,...  Interventional
# 3   relapsed, refractory, NKTR-255, CAR-T, daratum...  Interventional
# 4   Bempegaldesleukin (NKTR-214), NKTR-262, Nivolu...  Interventional
# 5   BEMPEG, Bempegaldesleukin, CD122, CD122-Biased...  Interventional
# 6   NKTR-214, Bempegaldesleukin, Nivolumab, Ipilim...  Interventional
# 7                HNSCC, CRC, R/R, NKTR-255, Cetuximab  Interventional
# 8   NKTR-214, Metastatic Urothelial Bladder Cancer...  Interventional
# 9                                                      Interventional
# 10  Phase 2a: Multiple solid tumor types, Phase 2b...  Interventional
# 11  CD122-Biased Agonist, CD122-Biased Cytokine, I...  Interventional
# 12  Open Label multicenter extension study advance...  Interventional
# 13  colorectal cancer, Colorectal cancer, second line  Interventional
# 14                                                     Interventional
# 15  Bladder, Bladder Cancer, CD122, Cisplatin Inel...  Interventional
# 16                                                     Interventional
# 17                                                     Interventional
# 18   Breast Cancer Brain Metastases (BCBM), Carcinoma  Interventional
# 19                                                     Interventional
# 20                                                     Interventional
# 21                                                     Interventional
# 22  Metastatic Solid Tumors, Locally Advanced Soli...  Interventional
#
#     DesignInterventionModel DesignPrimaryPurpose           EDGAR_name
# 0       Parallel Assignment            Treatment  Nektar Therapeutics
# 1       Parallel Assignment            Treatment  Nektar Therapeutics
# 2       Parallel Assignment            Treatment  Nektar Therapeutics
# 3     Sequential Assignment            Treatment  Nektar Therapeutics
# 4       Parallel Assignment            Treatment  Nektar Therapeutics
# 5       Parallel Assignment            Treatment  Nektar Therapeutics
# 6       Parallel Assignment            Treatment  Nektar Therapeutics
# 7     Sequential Assignment            Treatment  Nektar Therapeutics
# 8   Single Group Assignment            Treatment  Nektar Therapeutics
# 9       Parallel Assignment            Treatment  Nektar Therapeutics
# 10  Single Group Assignment            Treatment  Nektar Therapeutics
# 11      Parallel Assignment            Treatment  Nektar Therapeutics
# 12  Single Group Assignment            Treatment  Nektar Therapeutics
# 13      Parallel Assignment            Treatment  Nektar Therapeutics
# 14      Parallel Assignment            Treatment  Nektar Therapeutics
# 15  Single Group Assignment            Treatment  Nektar Therapeutics
# 16      Parallel Assignment            Treatment  Nektar Therapeutics
# 17  Single Group Assignment            Treatment  Nektar Therapeutics
# 18      Parallel Assignment            Treatment  Nektar Therapeutics
# 19      Parallel Assignment            Treatment  Nektar Therapeutics
# 20  Single Group Assignment            Treatment  Nektar Therapeutics
# 21      Parallel Assignment        Basic Science  Nektar Therapeutics
# 22  Single Group Assignment            Treatment  Nektar Therapeutics
#
# [23 rows x 58 columns]

# %%
clinical_trials_company_drugs("Nektar Therapeutics", ["Bempegaldesleukin", "NKTR-214"])
# Out:
#    Rank          OrgFullName        NCTId  \
# 0     3  Nektar Therapeutics  NCT03729245
# 1     5  Nektar Therapeutics  NCT03435640
# 2     6  Nektar Therapeutics  NCT04646044
# 3     7  Nektar Therapeutics  NCT02983045
# 4     9  Nektar Therapeutics  NCT03138889
# 5    12  Nektar Therapeutics  NCT04410445
# 6    16  Nektar Therapeutics  NCT03785925
# 7    23  Nektar Therapeutics  NCT02869295
#
#                                           BriefTitle  \
# 0  A Study of Bempegaldesleukin (NKTR-214: BEMPEG...
# 1  A Study of NKTR-262 in Combination With Bempeg...
# 2  A Placebo Controlled Trial of Bempegaldesleuki...
# 3  A Dose Escalation and Cohort Expansion Study o...
# 4  A Study of a CD122-Biased Cytokine (NKTR-214) ...
# 5  Study to Compare Adjuvant Immunotherapy of Bem...
# 6  A Single-Arm Study of Bempegaldesleukin (NKTR-...
# 7  A Phase 1/2 Multicenter Dose Escalation and Ex...
#
#                                        OfficialTitle DesignAllocation  \
# 0  A Phase 3 Randomized Open Label Study to Compa...       Randomized
# 1  A Phase 1/2, Open-label, Multicenter, Dose Esc...   Non-Randomized
# 2  A Phase 1b, Multicenter, Randomized, Double-Bl...       Randomized
# 3  A Phase 1/2, Open-label, Multicenter Study of ...   Non-Randomized
# 4  A Phase 1/2, Open-Label, Multicenter Study to ...   Non-Randomized
# 5  A Phase 3, Randomized, Open-label Study to Com...       Randomized
# 6  A Phase 2, Single-Arm Study of Bempegaldesleuk...              N/A
# 7  An Open-Label, Multicenter, Dose Escalation An...              N/A
#
#     Acronym             Phase           OverallStatus      DesignMasking  ...  \
# 0                     Phase 3              Recruiting  None (Open Label)  ...
# 1    REVEAL  Phase 1, Phase 2              Recruiting  None (Open Label)  ...
# 2                     Phase 1              Recruiting             Double  ...
# 3  PIVOT-02  Phase 1, Phase 2  Active, not recruiting  None (Open Label)  ...
# 4    PROPEL  Phase 1, Phase 2              Recruiting  None (Open Label)  ...
# 5  PIVOT-12           Phase 3              Recruiting  None (Open Label)  ...
# 6  PIVOT-10           Phase 2  Active, not recruiting  None (Open Label)  ...
# 7  NKTR-214  Phase 1, Phase 2               Completed  None (Open Label)  ...
#
#   LeadSponsorClass IsFDARegulatedDrug  \
# 0         INDUSTRY                Yes
# 1         INDUSTRY                Yes
# 2         INDUSTRY                Yes
# 3         INDUSTRY                Yes
# 4         INDUSTRY                Yes
# 5         INDUSTRY                Yes
# 6         INDUSTRY                Yes
# 7         INDUSTRY
#
#                                         BriefSummary  \
# 0  The main purpose of this study is to compare t...
# 1  Patients will receive intra-tumoral (IT) NKTR-...
# 2  The main purpose of this phase-1b, multicenter...
# 3  In this four-part study, NKTR-214 will be admi...
# 4  This study is to assess the safety and tolerab...
# 5  The main purpose of this study is to compare t...
# 6  The main purpose of this study is to evaluate ...
# 7  This is a first in human, open-label, sequenti...
#
#                                  DetailedDescription  \
# 0
# 1  Cancer treatments that couple pharmacological ...
# 2
# 3  NKTR-214 (investigational agent) is an IL-2 pa...
# 4  NKTR-214 is a cytokine (investigational agent)...
# 5  The main purpose of this study is to compare t...
# 6
# 7
#
#                                            Condition  \
# 0  Renal Cell Carcinoma, Metastatic Renal Cell Ca...
# 1  Melanoma, Merkel Cell Carcinoma, Triple Negati...
# 2                 Covid-19, Coronavirus Disease 2019
# 3  Melanoma, Renal Cell Carcinoma, Non Small Cell...
# 4  Non-Small Cell Lung Cancer, Melanoma, Urotheli...
# 5  Melanoma, Melanoma Stage III, Melanoma Stage I...
# 6      Urinary Bladder Neoplasm, Neoplasm Metastasis
# 7   Unspecified Adult Solid Tumor, Protocol Specific
#
#                                              Keyword       StudyType  \
# 0  Kidney Cancer, Kidney Neoplasms, Renal Cancer,...  Interventional
# 1  Bempegaldesleukin (NKTR-214), NKTR-262, Nivolu...  Interventional
# 2  BEMPEG, Bempegaldesleukin, CD122, CD122-Biased...  Interventional
# 3  NKTR-214, Bempegaldesleukin, Nivolumab, Ipilim...  Interventional
# 4  NKTR-214, Metastatic Urothelial Bladder Cancer...  Interventional
# 5  CD122-Biased Agonist, CD122-Biased Cytokine, I...  Interventional
# 6  Bladder, Bladder Cancer, CD122, Cisplatin Inel...  Interventional
# 7  Metastatic Solid Tumors, Locally Advanced Soli...  Interventional
#
#    DesignInterventionModel DesignPrimaryPurpose           EDGAR_name
# 0      Parallel Assignment            Treatment  Nektar Therapeutics
# 1      Parallel Assignment            Treatment  Nektar Therapeutics
# 2      Parallel Assignment            Treatment  Nektar Therapeutics
# 3      Parallel Assignment            Treatment  Nektar Therapeutics
# 4  Single Group Assignment            Treatment  Nektar Therapeutics
# 5      Parallel Assignment            Treatment  Nektar Therapeutics
# 6  Single Group Assignment            Treatment  Nektar Therapeutics
# 7  Single Group Assignment            Treatment  Nektar Therapeutics
#
# [8 rows x 58 columns]
